# %% [markdown]
# # Data cleaning

# %%
import pandas as pd

# %%
#loadiong data into a dataframe
df1 = pd.read_csv('../divvy-tripdata.csv', index_col=0)
df1.head()
# Out:
# C:\Users\extra\AppData\Local\Temp\ipykernel_2680\4034367027.py:2: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('../divvy-tripdata.csv', index_col=0)
#                  rideable_type           started_at             ended_at  \
# ride_id
# A847FADBBC638E45   docked_bike  2020-04-26 17:45:14  2020-04-26 18:12:03
# 5405B80E996FF60D   docked_bike  2020-04-17 17:08:54  2020-04-17 17:17:03
# 5DD24A79A4E006F4   docked_bike  2020-04-01 17:54:13  2020-04-01 18:08:36
# 2A59BBDF5CDBA725   docked_bike  2020-04-07 12:50:19  2020-04-07 13:02:31
# 27AD306C119C6158   docked_bike  2020-04-18 10:22:59  2020-04-18 11:15:54
#
#                             start_station_name start_station_id  \
# ride_id
# A847FADBBC638E45                  Eckhart Park               86
# 5405B80E996FF60D     Drake Ave & Fullerton Ave              503
# 5DD24A79A4E006F4          McClurg Ct & Erie St              142
# ...

# %%
#checking types of data
df12.dtypes
# Out:
# rideable_type                  object
# started_at             datetime64[ns]
# ended_at               datetime64[ns]
# start_station_name             object
# start_station_id               object
# end_station_name               object
# end_station_id                 object
# start_lat                     float64
# start_lng                     float64
# end_lat                       float64
# end_lng                       float64
# member_casual                  object
# Duration              timedelta64[ns]
# dtype: object

# %%
#removing empty values
df12 = df1.dropna()

# %%
#checking if all empty values were removed
df12.isna()
# Out:
#                   rideable_type  started_at  ended_at  start_station_name  \
# ride_id
# A847FADBBC638E45          False       False     False               False
# 5405B80E996FF60D          False       False     False               False
# 5DD24A79A4E006F4          False       False     False               False
# 2A59BBDF5CDBA725          False       False     False               False
# 27AD306C119C6158          False       False     False               False
# ...                         ...         ...       ...                 ...
# 03005DDB0F2F28E4          False       False     False               False
# B0B4E85DA43A9194          False       False     False               False
# 8D148DD47B59530B          False       False     False               False
# 0D1170BA18FD33D1          False       False     False               False
# 09B20DC75B5EA1E0          False       False     False               False
#
# ...

# %%
#change start_at and ended_at to datetime
df12['started_at'] = pd.to_datetime(df12['started_at'])
df12['ended_at'] = pd.to_datetime(df12['ended_at'])
# Out:
# C:\Users\extra\AppData\Local\Temp\ipykernel_2680\2226048168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['started_at'] = pd.to_datetime(df12['started_at'])
# C:\Users\extra\AppData\Local\Temp\ipykernel_2680\2226048168.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['ended_at'] = pd.to_datetime(df12['ended_at'])

# %%
df12
# Out:
#                   rideable_type          started_at            ended_at  \
# ride_id
# A847FADBBC638E45    docked_bike 2020-04-26 17:45:14 2020-04-26 18:12:03
# 5405B80E996FF60D    docked_bike 2020-04-17 17:08:54 2020-04-17 17:17:03
# 5DD24A79A4E006F4    docked_bike 2020-04-01 17:54:13 2020-04-01 18:08:36
# 2A59BBDF5CDBA725    docked_bike 2020-04-07 12:50:19 2020-04-07 13:02:31
# 27AD306C119C6158    docked_bike 2020-04-18 10:22:59 2020-04-18 11:15:54
# ...                         ...                 ...                 ...
# 03005DDB0F2F28E4   classic_bike 2022-11-09 14:22:29 2022-11-09 14:25:18
# B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:53 2022-11-22 17:31:29
# 8D148DD47B59530B   classic_bike 2022-11-06 13:04:05 2022-11-06 13:13:33
# 0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:29 2022-11-06 15:17:17
# 09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:28 2022-11-26 12:31:04
#
#                              start_station_name start_station_id  \
# ride_id
# ...

# %%
df12.dtypes
# Out:
# rideable_type                 object
# started_at            datetime64[ns]
# ended_at              datetime64[ns]
# start_station_name            object
# start_station_id              object
# end_station_name              object
# end_station_id                object
# start_lat                    float64
# start_lng                    float64
# end_lat                      float64
# end_lng                      float64
# member_casual                 object
# dtype: object

# %%
#creating a "duration" col
df12['Duration'] = df12['ended_at'] - df12['started_at']
# Out:
# C:\Users\extra\AppData\Local\Temp\ipykernel_2680\2585599750.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['Duration'] = df12['ended_at'] - df12['started_at']

# %%
df12
# Out:
#                   rideable_type          started_at            ended_at  \
# ride_id
# A847FADBBC638E45    docked_bike 2020-04-26 17:45:14 2020-04-26 18:12:03
# 5405B80E996FF60D    docked_bike 2020-04-17 17:08:54 2020-04-17 17:17:03
# 5DD24A79A4E006F4    docked_bike 2020-04-01 17:54:13 2020-04-01 18:08:36
# 2A59BBDF5CDBA725    docked_bike 2020-04-07 12:50:19 2020-04-07 13:02:31
# 27AD306C119C6158    docked_bike 2020-04-18 10:22:59 2020-04-18 11:15:54
# ...                         ...                 ...                 ...
# 03005DDB0F2F28E4   classic_bike 2022-11-09 14:22:29 2022-11-09 14:25:18
# B0B4E85DA43A9194   classic_bike 2022-11-22 16:57:53 2022-11-22 17:31:29
# 8D148DD47B59530B   classic_bike 2022-11-06 13:04:05 2022-11-06 13:13:33
# 0D1170BA18FD33D1   classic_bike 2022-11-06 09:41:29 2022-11-06 15:17:17
# 09B20DC75B5EA1E0  electric_bike 2022-11-26 11:59:28 2022-11-26 12:31:04
#
#                              start_station_name start_station_id  \
# ride_id
# ...

# %%
df12.dtypes
# Out:
# rideable_type                  object
# started_at             datetime64[ns]
# ended_at               datetime64[ns]
# start_station_name             object
# start_station_id               object
# end_station_name               object
# end_station_id                 object
# start_lat                     float64
# start_lng                     float64
# end_lat                       float64
# end_lng                       float64
# member_casual                  object
# Duration              timedelta64[ns]
# dtype: object

# %%
df12.dtypes
# Out:
# rideable_type                  object
# started_at             datetime64[ns]
# ended_at               datetime64[ns]
# start_station_name             object
# start_station_id               object
# end_station_name               object
# end_station_id                 object
# start_lat                     float64
# start_lng                     float64
# end_lat                       float64
# end_lng                       float64
# member_casual                  object
# Duration              timedelta64[ns]
# dtype: object

# %% [markdown]
# ### Checking for incorrect entries in the rideable and members cols

# %%
df12.rideable_type.unique()
# Out:
# array(['docked_bike', 'electric_bike', 'classic_bike'], dtype=object)

# %%
df12.member_casual.unique()
# Out:
# array(['member', 'casual'], dtype=object)

# %% [markdown]
# ### Saving data into a new file

# %%
df12.to_csv('../tripata.csv')
