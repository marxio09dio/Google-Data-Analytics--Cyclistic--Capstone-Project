# %% [markdown]
# # eheheh sir
# ### cleaningings datings

# %%
import pandas as pd

# %%
df1 = pd.read_csv('C:/Users/extra/Downloads/Data/Google Data Analytics (Cyclistic) Capstone Project/divvy-tripdata.csv', index_col=0)
df1
# Out:
# C:\Users\extra\AppData\Local\Temp\ipykernel_8248\1212645200.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('C:/Users/extra/Downloads/Data/Google Data Analytics (Cyclistic) Capstone Project/divvy-tripdata.csv', index_col=0)
#                   rideable_type           started_at             ended_at  \
# ride_id
# A847FADBBC638E45    docked_bike  2020-04-26 17:45:14  2020-04-26 18:12:03
# 5405B80E996FF60D    docked_bike  2020-04-17 17:08:54  2020-04-17 17:17:03
# 5DD24A79A4E006F4    docked_bike  2020-04-01 17:54:13  2020-04-01 18:08:36
# 2A59BBDF5CDBA725    docked_bike  2020-04-07 12:50:19  2020-04-07 13:02:31
# 27AD306C119C6158    docked_bike  2020-04-18 10:22:59  2020-04-18 11:15:54
# ...                         ...                  ...                  ...
# C349E243A9BAA6F7  electric_bike  2022-11-25 11:19:52  2022-11-25 11:31:50
# ...

# %%
#removing empty values
df12 = df1.dropna()

# %%
#checking if all empty values were removed
df12.isna()
# Out:
#                   rideable_type  started_at  ended_at  start_station_name  \
# ride_id
# A847FADBBC638E45          False       False     False               False
# 5405B80E996FF60D          False       False     False               False
# 5DD24A79A4E006F4          False       False     False               False
# 2A59BBDF5CDBA725          False       False     False               False
# 27AD306C119C6158          False       False     False               False
# ...                         ...         ...       ...                 ...
# 03005DDB0F2F28E4          False       False     False               False
# B0B4E85DA43A9194          False       False     False               False
# 8D148DD47B59530B          False       False     False               False
# 0D1170BA18FD33D1          False       False     False               False
# 09B20DC75B5EA1E0          False       False     False               False
#
# ...

# %%
df12.dtypes
# Out:
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
#listing types of rides
df12.rideable_type.unique()
# Out:
# array(['docked_bike', 'electric_bike', 'classic_bike'], dtype=object)

# %%
df12.rideable_type.value_counts()
# Out:
# classic_bike     5836546
# docked_bike      3020292
# electric_bike    2927916
# Name: rideable_type, dtype: int64

# %% [markdown]
# ### Types and number of rides
# 1. classic_bike     5836546
# 2. docked_bike      3020292
# 3. electric_bike    2927916

# %%
df12.member_casual.unique()
# Out:
# array(['member', 'casual'], dtype=object)

# %%
df12.member_casual.value_counts()
# Out:
# member    6757397
# casual    5027357
# Name: member_casual, dtype: int64

# %% [markdown]
# ### Types and number of customers
#
# 1. member    6757397
# 2. casual    5027357
